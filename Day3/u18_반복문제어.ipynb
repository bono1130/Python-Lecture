# %% [markdown]
# # Unit 18. 반복문 제어

# %% [markdown]
# ### 18.1 break

# %%
#주사위를 두 번 굴려서 눈의 합이 10 이상이면 탈출
import random

while True:
    dice1 = random.randint(1,6)
    dice2 = random.randint(1,6)
    print(f'({dice1},{dice2})', end = '  ')
    if dice1 + dice2 > 8:
        break
# Out:
# (2,1)  (5,1)  (3,5)  (3,3)  (5,3)  (5,3)  (3,3)  (5,4)

# %%
# for - break
# 1에서 몇까지 더하면 누적합이 300을 초과하는가?
cum_sum = 0
for i in range(100):
    cum_sum += i
    if cum_sum > 300:
        print(i, cum_sum)
        break
# Out:
# 25 325

# %%
# 중첩 반복문에서는 루프 1개만 탈출
for i in range(100):
    for k in range(i+1):
        break

# %% [markdown]
# ### 18.2 continue

# %%
# 홀수만 출력
for i in range(10):
    if i % 2 == 0:
        continue
    print(i, end = ' ')
# Out:
# 1 3 5 7 9

# %%
i = 0
while i < 10:
    i += 1
    if i % 2 == 0:
        continue
    print(i, end = ' ')
# Out:
# 1 3 5 7 9
