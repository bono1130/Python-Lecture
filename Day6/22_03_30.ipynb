# %% [markdown]
# - 27.6 심사문제: 특정 문자가 들어있는 단어 찾기

# %%
file = open('hello.txt', 'w')
file.write('Fortunately, however, for the reputation of Asteroid B-612, a Turkish dictator made a law that his subjects, under pain of death, should change to European costume. So in 1920 the astronomer gave his demonstration all over again, dressed with impressive style and elegance. And this time everybody accepted his report.')
file.close()

# %%
file = open('.txt', 'r')
text = list(file.read().split())
for word in text:
    if 'c' in word:
        print(word.strip(',.'))
file.close()
# Out:
# dictator
# subjects
# change
# costume
# elegance
# accepted

# %% [markdown]
# - 29.4 심사문제: 사칙 연산 함수 만들기

# %%
x, y = map(int, input().split())

def calc(x, y):
    return x+y, x-y, x*y, x/y

a, s, m, d = calc(x, y)
print('덧셈: {0}, 뺄셈: {1}, 곱셈: {2}, 나눗셈: {3}'.format(a, s, m, d))
# Out:
# 10 20
# 덧셈: 30, 뺄셈: -10, 곱셈: 200, 나눗셈: 0.5

# %% [markdown]
# - 30.7 심사문제: 가장 낮은 점수, 높은 점수와 평균 점수를 구하는 함수 만들기

# %%
korean, english, mathematics, science = map(int, input().split())

def get_min_max_score(*args):
    return min(args), max(args)
def get_average(**kwargs):
    return sum(kwargs.values())/len(kwargs)

min_score, max_score = get_min_max_score(korean, english, mathematics, science)
average_score = get_average(korean=korean, english=english, mathematics=mathematics, science=science)
print('낮은 점수: {0:.2f}, 높은 점수: {1:.2f}, 평균 점수: {2:.2f}'.format(min_score, max_score, average_score))
 
min_score, max_score = get_min_max_score(english, science)
average_score = get_average(english=english, science=science)
print('낮은 점수: {0:.2f}, 높은 점수: {1:.2f}, 평균 점수: {2:.2f}'.format(min_score, max_score, average_score))
# Out:
# 76 82 89 84
# 낮은 점수: 76.00, 높은 점수: 89.00, 평균 점수: 82.75
# 낮은 점수: 82.00, 높은 점수: 84.00, 평균 점수: 83.00

# %% [markdown]
# - 31.5 심사문제: 재귀호출로 피보나치 수 구하기

# %%
def fib(n):
    if n == 0:
        return 0
    elif n == 1 or n ==2:
        return 1
    return fib(n-1) + fib(n-2)

n = int(input())
print(fib(n))
# Out:
# 20
# 6765

# %% [markdown]
# - 32.5 심사문제: 파일 이름을 한꺼번에 바꾸기

# %%
files = input().split()

print(list(map(lambda x: '{0:03d}'.format(int(x.split('.')[0]))+ '.' + x.split('.')[1], files)))
# Out:
# 1.jpg 10.png 11.png 2.jpg 3.png
# ['001.jpg', '010.png', '011.png', '002.jpg', '003.png']

# %%
# %%shell
# jupyter nbconvert --to html /content/drive/MyDrive/"Colab Notebooks"/22_03_30.ipynb
# Out:
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Colab Notebooks/22_03_30.ipynb to html
# [NbConvertApp] Writing 286939 bytes to /content/drive/MyDrive/Colab Notebooks/22_03_30.html
