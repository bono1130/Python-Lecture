# %% [markdown]
# # Unit 12. 딕셔너리(Dictionary)

# %%
lux1 = [490, 334, 550, 18.72]
lux2 = {'health':490, 'mana':334, 'melee':550, 'armor':18.72}
lux2
# Out:
# {'armor': 18.72, 'health': 490, 'mana': 334, 'melee': 550}

# %%
armor = lux1[-1]
armor
# Out:
# 18.72

# %%
armor = lux2['armor']
armor
# Out:
# 18.72

# %% [markdown]
# ### 12.1 딕셔너리 만들기

# %%
# key값의 순서가 보장되지 않음
lux = {'health':490, 'mana':334, 'melee':550, 'armor':18.72}
lux
# Out:
# {'armor': 18.72, 'health': 490, 'mana': 334, 'melee': 550}

# %%
# key값 중복 시 맨 뒤의 값만 사용
lux = {'health':490, 'mana':334, 'melee':550, 'armor':18.72, 'mana':430}
lux
# Out:
# {'armor': 18.72, 'health': 490, 'mana': 430, 'melee': 550}

# %%
# OrderedDict는 순서가 보장됨
from collections import OrderedDict
d = OrderedDict()
d['health'] = 490
d['mana'] = 334
d['armor'] = 18.72
d
# Out:
# OrderedDict([('health', 490), ('mana', 334), ('armor', 18.72)])

# %% [markdown]
# - 빈 딕셔너리 생성

# %%
a = {}
b = dict()
type(a), type(b)
# Out:
# (dict, dict)

# %%
c = set([1,2,3])
type(c)
# Out:
# set

# %%
c
# Out:
# {1, 2, 3}

# %%
lux1 = dict(health=490, mana=334, melee=550, armor=18.72)           #키=값
lux1
# Out:
# {'armor': 18.72, 'health': 490, 'mana': 334, 'melee': 550}

# %%
keys = ['health', 'mana', 'melee', 'armor']
values = [490, 334, 550, 18.72]
list(zip(keys,values))
# Out:
# [('health', 490), ('mana', 334), ('melee', 550), ('armor', 18.72)]

# %%
lux2 = dict(zip(keys, values))
lux2
# Out:
# {'armor': 18.72, 'health': 490, 'mana': 334, 'melee': 550}

# %%
lux3 = dict([('health', 490), ('mana', 334), ('melee', 550), ('armor', 18.72)])
lux3
# Out:
# {'armor': 18.72, 'health': 490, 'mana': 334, 'melee': 550}

# %%
lux4 = dict({'health':490, 'mana':334, 'melee':550, 'armor':18.72})
lux4
# Out:
# {'armor': 18.72, 'health': 490, 'mana': 334, 'melee': 550}

# %% [markdown]
# - 추천 방법

# %%
lux = {'health':490, 'mana':334, 'melee':550, 'armor':18.72}
lux2 = dict(zip(keys, values))

# %% [markdown]
# ### 12.2 딕셔너리 키에 접근하고 값 할당하기

# %%
lux['mana']
# Out:
# 334

# %%
lux['armor'] = 21.34
lux
# Out:
# {'armor': 21.34, 'health': 490, 'mana': 334, 'melee': 550}

# %%
lux['new'] = 'Kim'
lux
# Out:
# {'armor': 21.34, 'health': 490, 'mana': 334, 'melee': 550, 'new': 'Kim'}

# %%
lux['origin']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-69b3bda4e409> in <module>()
# ----> 1 lux['origin']
#
# KeyError: 'origin'

# %% [markdown]
# - in 연산자 : key가 있는지 확인

# %%
'health' in lux
# Out:
# True

# %%
lux
# Out:
# {'armor': 21.34, 'health': 490, 'mana': 334, 'melee': 550, 'new': 'Kim'}
